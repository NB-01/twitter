# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import plotly.express as px

# %%
df = pd.read_csv('drewhouston.csv')
dfs = pd.read_csv('DBX.csv')

# %%
df1 = pd.DataFrame()

# %%
df1['created_at'] = df['created_at']
df1['created_at'] = pd.to_datetime(t_df['created_at'])
df1['date'] = df1['created_at'].dt.date
del df1['created_at']
df1['id'] = df['id']
df1['text'] = df['full_text']
df1['retweet_count'] = df['retweet_count']
df1['favorite_count'] = df['favorite_count']

# %%
df1.dtypes
# Out:
# id                         int64
# text                      object
# retweet_count              int64
# favorite_count             int64
# date              datetime64[ns]
# dtype: object

# %%
df1['date'] = pd.to_datetime(df1['date'])

# %%
df1
# Out:
#                       id                                               text  \
# 0    1456394103789277186  Proud of the team for another strong quarter! ...
# 1    1456105938201374727             Congrats Kyle! https://t.co/zymtCsGxz4
# 2    1454105958913691650  Excited for @getcommande to join the Dropbox f...
# 3    1453765978198732802  We're certainly supporting Apple Silicon, sorr...
# 4    1453763456398548993  @kfury @Dropbox @DropboxSupport Our communicat...
# ..                   ...                                                ...
# 463            976758647  Josh Groban singing Disarm... my inner 14-year...
# 464            912279893  @guykawasaki wish for more dropbox space granted!
# 465            900233191  @bellanyc1 what happened? email us beta@getdro...
# 466            811537015                      @kmore thanks for the love :)
# 467            785593826  @fyc and other folks who got "invalid beta cod...
#
#      retweet_count  favorite_count       date
# ...

# %%
dfs
# Out:
#            Date       Open       High        Low      Close  Adj Close  \
# 0    2018-03-23  29.000000  31.600000  27.840000  28.480000  28.480000
# 1    2018-03-26  30.450001  30.660000  27.750000  30.450001  30.450001
# 2    2018-03-27  30.410000  30.680000  29.000000  29.900000  29.900000
# 3    2018-03-28  29.260000  31.190001  28.610001  30.980000  30.980000
# 4    2018-03-29  31.980000  34.367001  30.790001  31.250000  31.250000
# ..          ...        ...        ...        ...        ...        ...
# 925  2021-11-23  24.500000  25.030001  23.950001  24.520000  24.520000
# 926  2021-11-24  24.250000  24.820000  24.250000  24.530001  24.530001
# 927  2021-11-26  24.420000  24.684000  24.165001  24.340000  24.340000
# 928  2021-11-29  24.350000  24.969999  24.080000  24.950001  24.950001
# 929  2021-11-30  24.860001  24.959999  24.174999  24.610001  24.610001
#
#        Volume
# 0    56108700
# 1    16985700
# 2     6911000
# 3     5113300
# 4    15800200
# ..        ...
# ...

# %%
dfs.dtypes
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Adj Close           float64
# Volume                int64
# dtype: object

# %%
dfs['Date'] = pd.to_datetime(dfs['Date'])

# %%
dfs.rename(columns={'Date':'date'}, inplace=True)

# %%
df_new = pd.merge(df1, dfs, on='date', how='left')

# %%
df1.dtypes
# Out:
# id                         int64
# text                      object
# retweet_count              int64
# favorite_count             int64
# date              datetime64[ns]
# dtype: object

# %%
dfs.head()
# Out:
#         Date       Open       High        Low      Close  Adj Close    Volume
# 0 2018-03-23  29.000000  31.600000  27.840000  28.480000  28.480000  56108700
# 1 2018-03-26  30.450001  30.660000  27.750000  30.450001  30.450001  16985700
# 2 2018-03-27  30.410000  30.680000  29.000000  29.900000  29.900000   6911000
# 3 2018-03-28  29.260000  31.190001  28.610001  30.980000  30.980000   5113300
# 4 2018-03-29  31.980000  34.367001  30.790001  31.250000  31.250000  15800200

# %%
df_new
# Out:
#                       id                                               text  \
# 0    1456394103789277186  Proud of the team for another strong quarter! ...
# 1    1456105938201374727             Congrats Kyle! https://t.co/zymtCsGxz4
# 2    1454105958913691650  Excited for @getcommande to join the Dropbox f...
# 3    1453765978198732802  We're certainly supporting Apple Silicon, sorr...
# 4    1453763456398548993  @kfury @Dropbox @DropboxSupport Our communicat...
# ..                   ...                                                ...
# 463            976758647  Josh Groban singing Disarm... my inner 14-year...
# 464            912279893  @guykawasaki wish for more dropbox space granted!
# 465            900233191  @bellanyc1 what happened? email us beta@getdro...
# 466            811537015                      @kmore thanks for the love :)
# 467            785593826  @fyc and other folks who got "invalid beta cod...
#
# ...

# %%
df_new.info
# Out:
# <bound method DataFrame.info of                       id                                               text  \
# 0    1456394103789277186  Proud of the team for another strong quarter! ...
# 1    1456105938201374727             Congrats Kyle! https://t.co/zymtCsGxz4
# 2    1454105958913691650  Excited for @getcommande to join the Dropbox f...
# 3    1453765978198732802  We're certainly supporting Apple Silicon, sorr...
# 4    1453763456398548993  @kfury @Dropbox @DropboxSupport Our communicat...
# ..                   ...                                                ...
# 463            976758647  Josh Groban singing Disarm... my inner 14-year...
# 464            912279893  @guykawasaki wish for more dropbox space granted!
# 465            900233191  @bellanyc1 what happened? email us beta@getdro...
# 466            811537015                      @kmore thanks for the love :)
# 467            785593826  @fyc and other folks who got "invalid beta cod...
#
# ...

# %%
plt.plot(dfs.date, dfs.Close)
#plt.plot(dfs.date, df_new.date)

# %%
for i in range(len(dfs)-1):
    dfs['var'].iloc[i]= np.log(dfs['Close'].iloc[i]/dfs['Close'].iloc[i+1])

# %%
dfs['Close'].iloc[4]
# Out:
# 31.25

# %%
dfs
# Out:
#           date       Open       High        Low      Close  Adj Close  \
# 0   2018-03-23  29.000000  31.600000  27.840000  28.480000  28.480000
# 1   2018-03-26  30.450001  30.660000  27.750000  30.450001  30.450001
# 2   2018-03-27  30.410000  30.680000  29.000000  29.900000  29.900000
# 3   2018-03-28  29.260000  31.190001  28.610001  30.980000  30.980000
# 4   2018-03-29  31.980000  34.367001  30.790001  31.250000  31.250000
# ..         ...        ...        ...        ...        ...        ...
# 925 2021-11-23  24.500000  25.030001  23.950001  24.520000  24.520000
# 926 2021-11-24  24.250000  24.820000  24.250000  24.530001  24.530001
# 927 2021-11-26  24.420000  24.684000  24.165001  24.340000  24.340000
# 928 2021-11-29  24.350000  24.969999  24.080000  24.950001  24.950001
# 929 2021-11-30  24.860001  24.959999  24.174999  24.610001  24.610001
#
#        Volume       var
# 0    56108700 -0.066884
# 1    16985700  0.018228
# 2     6911000 -0.035483
# 3     5113300 -0.008678
# ...

# %%
plt.plot('date', 'var', data=dfs)

# %%
df1
# Out:
#                       id                                               text  \
# 0    1456394103789277186  Proud of the team for another strong quarter! ...
# 1    1456105938201374727             Congrats Kyle! https://t.co/zymtCsGxz4
# 2    1454105958913691650  Excited for @getcommande to join the Dropbox f...
# 3    1453765978198732802  We're certainly supporting Apple Silicon, sorr...
# 4    1453763456398548993  @kfury @Dropbox @DropboxSupport Our communicat...
# ..                   ...                                                ...
# 463            976758647  Josh Groban singing Disarm... my inner 14-year...
# 464            912279893  @guykawasaki wish for more dropbox space granted!
# 465            900233191  @bellanyc1 what happened? email us beta@getdro...
# 466            811537015                      @kmore thanks for the love :)
# 467            785593826  @fyc and other folks who got "invalid beta cod...
#
#      retweet_count  favorite_count       date
# ...

# %%
dfs
# Out:
#           date       Open       High        Low      Close  Adj Close  \
# 0   2018-03-23  29.000000  31.600000  27.840000  28.480000  28.480000
# 1   2018-03-26  30.450001  30.660000  27.750000  30.450001  30.450001
# 2   2018-03-27  30.410000  30.680000  29.000000  29.900000  29.900000
# 3   2018-03-28  29.260000  31.190001  28.610001  30.980000  30.980000
# 4   2018-03-29  31.980000  34.367001  30.790001  31.250000  31.250000
# ..         ...        ...        ...        ...        ...        ...
# 925 2021-11-23  24.500000  25.030001  23.950001  24.520000  24.520000
# 926 2021-11-24  24.250000  24.820000  24.250000  24.530001  24.530001
# 927 2021-11-26  24.420000  24.684000  24.165001  24.340000  24.340000
# 928 2021-11-29  24.350000  24.969999  24.080000  24.950001  24.950001
# 929 2021-11-30  24.860001  24.959999  24.174999  24.610001  24.610001
#
#        Volume       var
# 0    56108700 -0.066884
# 1    16985700  0.018228
# 2     6911000 -0.035483
# 3     5113300 -0.008678
# ...

# %%
fig, ax = plt.subplots(1,2)
plt.plot(dfs.date, dfs.Volume)
plt.plot(df1.date, df1.favorite_count)
plt.tight_layout()
plt.show()
